# %%
#import libraries
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import opendatasets as od

# %%
#download dataset
od.download("https://www.kaggle.com/datasets/prathamsaraf1389/spotify-global-top-50-daily-update")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sitifatim
# Your Kaggle Key: ········
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 7.97M/7.97M [00:15<00:00, 525kB/s]

# %%
#load data
df = pd.read_csv("spotify-global-top-50-daily-update/playlist.csv")

# %%
df
# Out:
#                                  track_name track_add_date track_add_time  \
# 0                                   Flowers     2023-03-31       10:02:16
# 1                                 Kill Bill     2023-03-31       10:02:16
# 2                                       TQG     2023-03-31       10:02:16
# 3                                      BESO     2023-03-31       10:02:16
# 4                        Boy's a liar Pt. 2     2023-03-31       10:02:16
# ..                                      ...            ...            ...
# 295                                  Snooze     2023-04-05       09:37:18
# 296                                   Bones     2023-04-05       09:37:18
# 297       All Of The Girls You Loved Before     2023-04-05       09:37:18
# 298                             Eyes Closed     2023-04-05       09:37:18
# 299  Arcángel: Bzrp Music Sessions, Vol. 54     2023-04-05       09:37:18
#
#      multiple_artists_bool                  name_of_artists  \
# ...

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 15 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   track_name                    300 non-null    object
#  1   track_add_date                300 non-null    object
#  2   track_add_time                300 non-null    object
#  3   multiple_artists_bool         300 non-null    bool
#  4   name_of_artists               300 non-null    object
#  5   album_name                    300 non-null    object
#  6   album_release_date            300 non-null    object
#  7   album_release_date_precision  300 non-null    object
#  8   number_of_tracks_in_album     300 non-null    int64
#  9   position_in_playlist          300 non-null    int64
#  10  track_duration_ms             300 non-null    int64
#  11  track_popularity              300 non-null    int64
# ...

# %% [markdown]
# ## Explanatory Data Analyst

# %% [markdown]
# ### Basic Data Information

# %%
#describe
df.describe()
# Out:
#        number_of_tracks_in_album  position_in_playlist  track_duration_ms  \
# count                 300.000000            300.000000         300.000000
# mean                    9.876667             25.500000      196878.183333
# std                     8.890346             14.454981       35838.844234
# min                     1.000000              1.000000      112087.000000
# 25%                     1.000000             13.000000      167303.000000
# 50%                    10.000000             25.500000      198435.000000
# 75%                    17.000000             38.000000      221520.000000
# max                    36.000000             50.000000      272373.000000
#
#        track_popularity
# count        300.000000
# mean          86.596667
# std           13.703037
# min            0.000000
# 25%           87.000000
# 50%           90.000000
# 75%           92.000000
# max           97.000000

# %%
df.describe(include='O')
# Out:
#        track_name track_add_date track_add_time name_of_artists album_name  \
# count         300            300            300             300        300
# unique         59              6              6              53         55
# top       Flowers     2023-03-31       10:02:16       ['Jimin']    Starboy
# freq            6             50             50              17         12
#
#        album_release_date album_release_date_precision  \
# count                 300                          300
# unique                 46                            1
# top            2023-03-17                          day
# freq                   23                          300
#
#                              images_path data_collection_date
# count                                300                  300
# unique                                59                    6
# top     ./images/flowers_miley_cyrus.jpg           2023-03-31
# freq                                   6                   50

# %% [markdown]
# From dataset description, some basic informations that we can see:
# * There are total 300 tracks on the dataset
# * Maximun popularity in 87
# * Popular track name is Flowers
# * Popular artist i
